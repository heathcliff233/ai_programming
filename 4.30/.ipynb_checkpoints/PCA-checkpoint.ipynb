# %% [markdown]
# # 降维与可视化
# 洪亮 181240019
# 2019.5.1

# %% [markdown]
# ### Contents
# ----
#
# * [直接调用](#zj)
#     * [PCA](#pca)
#         * [t-SNE.PCA](#t-SNE.PCA)
#         * [PCA](#PCA)
#         * [Kernel-PCA]()
#     * [manifold]()
#         * [MDS]()
#         * [Isomap]()
# * [手工计算](#cal)
#     * [PCA]()
#     * [t-SNE]()

# %% [markdown]
# ### 直接调用

# %% [markdown]
# #### PCA <a id="pca"></a>

# %% [markdown]
# ##### t-SNE.PCA <a class="anchor" id="t-SNE.PCA"></a>

# %%
from sklearn import manifold,datasets
from sklearn import decomposition
import matplotlib.pyplot as plt
# %matplotlib inline
digits = datasets.load_digits()
x = digits.data
y = digits.target
tsne = manifold.TSNE(n_components=2,init='pca')
x_t = tsne.fit_transform(x)
norm_t = (x_t - x_t.min())/(x_t.max() - x_t.min())
plt.figure(figsize=(8,8),dpi=300)
for i in range(norm_t.shape[0]):
    plt.text(norm_t[i][0],norm_t[i][1],str(y[i]),color=plt.cm.Set1(y[i]),fontdict={'weight':'bold'})
plt.title('t-SNE')
plt.show()

# %% [markdown]
# ##### PCA <a class="anchor" id="PCA"></a>

# %%
pca = decomposition.PCA(n_components=2)
x_p = pca.fit_transform(x)
norm_p = (x_p - x_p.min())/(x_p.max() - x_p.min())
plt.figure(figsize=(8,8),dpi=300)
for i in range(norm_p.shape[0]):
    plt.text(norm_p[i][0],norm_p[i][1],str(y[i]),color=plt.cm.Set1(y[i]),fontdict={'weight':'bold'})
plt.title('PCA')
plt.show()

# %% [markdown]
# #### Kernel-PCA

# %%
k_pca = decomposition.KernelPCA(n_components=2)
x_k = k_pca.fit_transform(x)
norm_k = (x_k - x_k.min())/(x_k.max() - x_k.min())
plt.figure(figsize=(8,8),dpi=300)
for i in range(norm_k.shape[0]):
    plt.text(norm_k[i][0],norm_k[i][1],str(y[i]),color=plt.cm.Set1(y[i]),fontdict={'weight':'bold'})
plt.title('KernelPCA')
plt.show()

# %% [markdown]
# #### MDS

# %%
mds = manifold.MDS(n_components=2)
x_m = mds.fit_transform(x)
norm_m = (x_m - x_m.min())/(x_m.max() - x_m.min())
plt.figure(figsize=(8,8),dpi=300)
for i in range(norm_m.shape[0]):
    plt.text(norm_m[i][0],norm_m[i][1],str(y[i]),color=plt.cm.Set1(y[i]),fontdict={'weight':'bold'})
plt.title('MDS')
plt.show()

# %% [markdown]
# #### Isomap

# %%
iso = manifold.Isomap(n_components=2)
x_i = iso.fit_transform(x)
norm_i = (x_i - x_i.min())/(x_i.max() - x_i.min())
plt.figure(figsize=(8,8),dpi=300)
for i in range(norm_i.shape[0]):
    plt.text(norm_i[i][0],norm_i[i][1],str(y[i]),color=plt.cm.Set1(y[i]),fontdict={'weight':'bold'})
plt.title('Isomap')
plt.show()

# %% [markdown]
# #### 手工解法

# %% [markdown]
# #### PCA

# %%
import seaborn
import numpy as np
import pandas as pd

# %%
a = seaborn.load_dataset('titanic')

# %%
a.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
b = a.loc[:,'survived':'pclass']

# %%
b['sibsp'] = a.loc[:,'sibsp']
b['parch'] = a.loc[:,'parch']

# %%
b.head()
# Out:
#    survived  pclass  sibsp  parch
# 0         0       3      1      0
# 1         1       1      1      0
# 2         1       3      0      0
# 3         1       1      1      0
# 4         0       3      0      0

# %%
b = b-b.mean()

# %%
b.corr()
# Out:
#           survived    pclass     sibsp     parch
# survived  1.000000 -0.338481 -0.035322  0.081629
# pclass   -0.338481  1.000000  0.083081  0.018443
# sibsp    -0.035322  0.083081  1.000000  0.414838
# parch     0.081629  0.018443  0.414838  1.000000

# %%
arr = np.array(b.corr())

# %%
arr
# Out:
# array([[ 1.        , -0.33848104, -0.0353225 ,  0.08162941],
#        [-0.33848104,  1.        ,  0.08308136,  0.01844267],
#        [-0.0353225 ,  0.08308136,  1.        ,  0.4148377 ],
#        [ 0.08162941,  0.01844267,  0.4148377 ,  1.        ]])

# %%
eigenvalues, eigenvectors = np.linalg.eig(arr)

# %%
eigenvalues
# Out:
# array([0.66174628, 0.56687552, 1.3403996 , 1.4309786 ])

# %%
idx = eigenvalues.argsort()[::-1]

# %%
idx
# Out:
# array([3, 2, 0, 1])

# %%
eigenvectors = eigenvectors[:, idx]
eigenvectors = eigenvectors[:, :2]

# %%
re = np.matmul(b, eigenvectors)

# %%
re
# Out:
# array([[ 0.33939471,  0.75682947],
#        [-0.38659205, -1.21545784],
#        [-0.50810071,  0.2024685 ],
#        ...,
#        [ 1.63266286,  0.15416358],
#        [-1.07671355, -1.07624835],
#        [-0.35072679,  0.89603895]])

# %%
x = [a[0] for a in re]
y = [a[1] for a in re]

# %%
seaborn.scatterplot(x = x , y = y)

# %% [markdown]
# #### TSNE

# %%
import numpy as np
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2).fit_transform(b)
X_embedded.shape
# Out:
# (891, 2)

# %%
x1 = [m[0] for m in X_embedded]
y1 = [m[1] for m in X_embedded]

# %%
seaborn.scatterplot(x = x1 , y = y1)

# %% [markdown]
# > **Reference**
# > [PCA的数学原理](http://blog.codinglabs.org/articles/pca-tutorial.html)
# > [主成分分析](http://deeplearning.stanford.edu/wiki/index.php/主成分分析)
# > [PCA源码](https://github.com/RRdmlearning/Machine-Learning-From-Scratch/tree/master/pca)
# > [sklearn.manifold.TSNE](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html)

# %% [markdown]
# **感觉效果最好的是 t-SNE 和 Isomap**
